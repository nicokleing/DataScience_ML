# %% [markdown]
# # Code Academy Project
#
# ## Introduction
#
# This project will investigate if there is a strong correlation between the economic output of a country and the life expectancy of its citizens.
#
# The goals are to prepare data, followed by analysis with plots, and seek to explain the findings from the study.
#
# Here are a few questions that this project will seek to answer:
#
# + Has life expectancy increased over time in the six nations?
# + Has GDP increased over time in the six nations?
# + Is there a correlation between GDP and life expectancy of a country?
# + What is the average life expectancy in these nations?
# + What is the distribution of that life expectancy?
#
# **Data sources**
#
# - GDP Source: [World Bank](https://data.worldbank.org/indicator/NY.GDP.MKTP.CD) national accounts data, and OECD National Accounts data files.
#
# - Life expectancy Data Source: [World Health Organization](http://apps.who.int/gho/data/node.main.688)

# %% [markdown]
# ## Import Python Modules
#
# First import the preliminary modules that will be used in this project:

# %%
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("all_data.csv")
df.head()
# Out:
#   Country  Year  Life expectancy at birth (years)           GDP
# 0   Chile  2000                              77.3  7.786093e+10
# 1   Chile  2001                              77.3  7.097992e+10
# 2   Chile  2002                              77.8  6.973681e+10
# 3   Chile  2003                              77.9  7.564346e+10
# 4   Chile  2004                              78.0  9.921039e+10

# %%
df.shape
# Out:
# (96, 4)

# %% [markdown]
# # Exploring the Data

# %%
print(df.Country.unique())
# Out:
# ['Chile' 'China' 'Germany' 'Mexico' 'United States of America' 'Zimbabwe']

# %%
print(df.Year.unique())
# Out:
# [2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013
#  2014 2015]

# %% [markdown]
# #### Cleaning Column Name

# %%
df = df.rename({"Life expectancy at birth (years)":"LEABY"}, axis = "columns")
df.head()
# Out:
#   Country  Year  LEABY           GDP
# 0   Chile  2000   77.3  7.786093e+10
# 1   Chile  2001   77.3  7.097992e+10
# 2   Chile  2002   77.8  6.973681e+10
# 3   Chile  2003   77.9  7.564346e+10
# 4   Chile  2004   78.0  9.921039e+10

# %%
plt.figure(figsize=(8,6))
sns.histplot(df.GDP, kde=False)
sns.rugplot(df.GDP)
plt.xlabel("GDP in Trillions of U.S. Dollars")
plt.show()
# Out:
# C:\Users\nicol\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\nicol\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(8,6))

sns.histplot(df.GDP, bins=20, color='skyblue', alpha=0.7)

sns.rugplot(df.GDP, height=0.1, color='red')

plt.xlabel("GDP in Trillions of U.S. Dollars")
plt.ylabel("Frequency")
plt.title("Distribution of GDP")
plt.show()
# Out:
# C:\Users\nicol\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\nicol\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))

# Gráfico de densidad
sns.kdeplot(df.LEABY, color='skyblue', fill=True)

# Histograma
sns.histplot(df.LEABY, bins=20, color='lightgray', kde=False)

plt.xlabel("Life expectancy at birth (years)")
plt.ylabel("Frequency")
plt.title("Distribution of Life Expectancy at Birth")
plt.show()
# Out:
# C:\Users\nicol\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\nicol\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))


sns.histplot(df.LEABY, bins=20, kde=True, color='lightblue', edgecolor='black', linewidth=1.5, stat='density')


sns.kdeplot(df.LEABY, color='blue', linewidth=2.5)

plt.xlabel("Life expectancy at birth (years)")
plt.ylabel("Density")
plt.title("Distribution of Life Expectancy at Birth")
plt.grid(True)
plt.show()
# Out:
# C:\Users\nicol\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\nicol\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(8,6))
sns.distplot(df.LEABY, rug = True, kde=False)
plt.xlabel("Life expectancy at birth (years)");
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_30076\4191344845.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.LEABY, rug = True, kde=False)
# C:\Users\nicol\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))


sns.histplot(df.LEABY, kde=False, color='skyblue', edgecolor='black')


sns.rugplot(df.LEABY, color='red')


sns.kdeplot(df.LEABY, color='green', linewidth=2.5)

plt.xlabel("Life expectancy at birth (years)")
plt.ylabel("Frequency")
plt.title("Distribution of Life Expectancy at Birth")
plt.show()
# Out:
# C:\Users\nicol\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\nicol\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\nicol\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(8,6))
sns.kdeplot(df.LEABY, shade=True)
plt.xlabel("Life expectancy at birth (years)")
plt.show()
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_30076\1179905032.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df.LEABY, shade=True)
# C:\Users\nicol\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x=df.LEABY)
plt.xlabel("Life expectancy at birth (years)")
plt.show()

# %% [markdown]
# # Media

# %%
dfMeans = df.drop("Year", axis = 1).groupby("Country").mean().reset_index()

# %%
dfMeans
# Out:
#                     Country     LEABY           GDP
# 0                     Chile  78.94375  1.697888e+11
# 1                     China  74.26250  4.957714e+12
# 2                   Germany  79.65625  3.094776e+12
# 3                    Mexico  75.71875  9.766506e+11
# 4  United States of America  78.06250  1.407500e+13
# 5                  Zimbabwe  50.09375  9.062580e+09

# %%
plt.figure(figsize=(8,6))
sns.barplot(x="LEABY", y="Country", data=dfMeans)
plt.xlabel("Life expectancy at birth (years)");

# %% [markdown]
# # Moda

# %%
dfMode = df.drop("Year", axis=1).groupby("Country").apply(lambda x: x.mode().iloc[0]).reset_index(drop=True)

# %%
dfMode
# Out:
# 0                   Country  LEABY           GDP
# 0                     Chile   77.3  6.973681e+10
# 1                     China   71.7  1.211350e+12
# 2                   Germany   80.6  1.949950e+12
# 3                    Mexico   75.0  6.836480e+11
# 4  United States of America   77.5  1.030000e+13
# 5                  Zimbabwe   44.3  4.415703e+09

# %%
plt.figure(figsize=(8,6))
sns.barplot(x="LEABY", y="Country", data=dfMode)
plt.xlabel("Life expectancy at birth (years)");

# %%
plt.figure(figsize=(8,6))
sns.barplot(x="GDP", y="Country", data=dfMeans)
plt.xlabel("GDP in Trillions of U.S. Dollars");

# %% [markdown]
# #### Violin Plots

# %% [markdown]
# Another way to compare data is to visualize the distributions of each and to look for patterns in the shapes.
#
# The violin plot is a popular choice because it can show the shape of the distribution compared to the box plot. Below, country is on the x-axis and the distribution of numeric columns : `GDP` and `LEABY` are on the y axis.
#
# In the `GDP` plot on the left, China and the US have a relatively wide range, where Zimbabwe, Chile, and Mexico have shorter ranges.
#
# In the `LEABY` plot, many of the countries have shorter ranges except for Zimbabwe which has a range spanning from the high 30s to the high 60s.

# %%
fig, axes = plt.subplots(1, 2, sharey=True, figsize=(15, 5))
axes[0] = sns.violinplot(ax=axes[0], x=df.GDP, y=df.Country)
axes[0].set_xlabel("GDP in Trillions of U.S. Dollars")
axes[1] = sns.violinplot(ax=axes[1], x=df.LEABY, y=df.Country)
axes[1].set_xlabel("Life expectancy at birth (years)");

# %% [markdown]
# #### Swarm Plots

# %%
fig, axes = plt.subplots(1, 2, sharey=True, figsize=(15, 5))

sns.swarmplot(ax=axes[0], x='GDP', y='Country', data=df, hue='Country', palette='Set2')
axes[0].set_xlabel("GDP in Trillions of U.S. Dollars")

sns.swarmplot(ax=axes[1], x='LEABY', y='Country', data=df, hue='Country', palette='Set2')
axes[1].set_xlabel("Life expectancy at birth (years)")

plt.show()
# Out:
# C:\Users\nicol\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\nicol\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\nicol\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 56.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\nicol\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
fig, axes = plt.subplots(1, 2, sharey=True, figsize=(15, 5))

sns.violinplot(ax=axes[0], x='GDP', y='Country', data=df, color='lightgray', inner=None)
sns.swarmplot(ax=axes[0], x='GDP', y='Country', data=df, hue='Country', palette='Set2', dodge=True)
axes[0].set_xlabel("GDP in Trillions of U.S. Dollars")

sns.violinplot(ax=axes[1], x='LEABY', y='Country', data=df, color='lightgray', inner=None)
sns.swarmplot(ax=axes[1], x='LEABY', y='Country', data=df, hue='Country', palette='Set2', dodge=True)
axes[1].set_xlabel("Life expectancy at birth (years)")

plt.show()
# Out:
# C:\Users\nicol\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\nicol\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\nicol\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 56.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\nicol\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(data=df, x='Year', y='GDP', hue='Country', palette='Set1', linewidth=2.5)
plt.title("GDP Over Time by Country")
plt.xlabel("Year")
plt.ylabel("GDP in Trillions of U.S. Dollars")
plt.legend(title='Country', loc='center left', bbox_to_anchor=(1, 0.5), ncol=1)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\nicol\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\nicol\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
graphGDP = sns.FacetGrid(df, col="Country", col_wrap=3,
                      hue = "Country", sharey = False)

graphGDP = (graphGDP.map(sns.lineplot,"Year","GDP")
         .add_legend()
         .set_axis_labels("Year","GDP in Trillions of U.S. Dollars"))

graphGDP;
# Out:
# C:\Users\nicol\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\nicol\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\nicol\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
plt.figure(figsize=(8,6))
sns.lineplot(x=df.Year, y=df.LEABY, hue=df.Country)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=1)
plt.ylabel("Life expectancy at birth (years)");
# Out:
# C:\Users\nicol\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\nicol\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import seaborn as sns
import matplotlib.pyplot as plt


graphLEABY = sns.FacetGrid(df, col="Country", col_wrap=3, hue="Country", sharey=False, height=4)


graphLEABY.map(sns.lineplot, "Year", "LEABY", marker='o', markersize=5, linewidth=2)


graphLEABY.set_titles(col_template="{col_name}")


graphLEABY.add_legend(title='Country')


graphLEABY.set_axis_labels("Year", "Life expectancy at birth (years)")


plt.tight_layout()


plt.show()
# Out:
# C:\Users\nicol\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\nicol\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\nicol\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))


sns.scatterplot(data=df, x='LEABY', y='GDP', hue='Country', palette='Set1', s=100, marker='o')


plt.title('Life Expectancy at Birth vs GDP')
plt.xlabel('Life Expectancy at Birth (years)')
plt.ylabel('GDP in Trillions of U.S. Dollars')


plt.legend(title='Country', loc='center left', bbox_to_anchor=(1, 0.5), ncol=1)


plt.grid(True)


plt.tight_layout()


plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

graph = sns.FacetGrid(df, col="Country", col_wrap=3, hue="Country", sharey=False, sharex=False, height=4)

graph.map(sns.scatterplot, "LEABY", "GDP", s=150, alpha=0.7)

graph.add_legend(title='Country', bbox_to_anchor=(1, 1), loc='upper left')

graph.set_axis_labels("Life expectancy at birth (years)", "GDP in Trillions of U.S. Dollars")

plt.tight_layout()

plt.show()
# Out:
# C:\Users\nicol\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\nicol\AppData\Local\Temp\ipykernel_30076\1513569136.py:12: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %% [markdown]
# ## Conclusions

# %% [markdown]
# This project was able to make quite a few data visualizations with the data even though there were only 96 rows and 4 columns.
#
# The project was also able to answer some of the questions posed in the beginning:
#
# - Has life expectancy increased over time in the six nations?
#     - Yes with Zimbabwe having the greatest increase.
# - Has GDP increased over time in the six nations?
#     - GDP has also increased for all countries in our list, especially for China.
# - Is there a correlation between GDP and life expectancy of a country?
#     - Yes there is a positive correlation between GDP and life expectancy for countries in our list.
# - What is the average life expectancy in these nations?
#     - Average life expectancy was between mid to high 70s for the countries except for Zimbabwe which was 50.
# - What is the distribution of that life expectancy?
#     - the life expectancy had a left skew, or most of the observations were on the right side.
